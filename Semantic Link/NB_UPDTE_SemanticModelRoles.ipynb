# %% [markdown]
# # Semantic model security updates
# This notebook helps to configure security on an existing semantic model. RLS roles can be scripted and added to the model. Use case could be to run this notebook regularly in case security may be overwritten by a semantic model update.

# %%
# Import libraries
# %pip install semantic-link-labs
import sempy.fabric as fabric
import sempy_labs as labs
from sempy_labs import tom
# Out:
# StatementMeta(, ee32384f-bec9-44d2-973f-20a9cc90ed03, 8, Finished, Available, Finished)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.7/764.7 kB 102.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 191.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 43.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 66.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 1.30.2
#     Not uninstalling azure-core at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-ca1a7ad2-f1cd-421b-a4af-54adf8d64c15
#     Can't uninstall 'azure-core'. No files were found to uninstall.
#   Attempting uninstall: semantic-link-sempy
# ...

# %%
semanticmodel_name = "AW2020" # specify semantic model name or id
workspace_id = fabric.get_workspace_id() # Retrieves the workspace id in which the notebook is running
# Out:
# StatementMeta(, 8c6137ab-72e2-443f-92dc-b7ed3872a56d, 23, Finished, Available, Finished)

# %%
# Create a read/write TOM connection
# This cell takes the semantic model definition in memory
tw = tom.TOMWrapper(
    dataset = semanticmodel_name,
    workspace = workspace_id,
    readonly = False
)
# Out:
# StatementMeta(, 8c6137ab-72e2-443f-92dc-b7ed3872a56d, 25, Finished, Available, Finished)

# %%
# This cell updates the in memory semantic model definition. 
# No changes are applied to the model yet

rolename = "test"
roledescription = "test description"

try:
    # Try to create a new role
    tw.add_role(
        role_name = rolename, 
        model_permission = None,  # defaults to Read
        description = roledescription
    )

    tw.add_role_member(
        role_name = olename, 
        member = "user1@example.com", # fill in user email for users
        role_member_type = "User"  # "User" or "Group"
    )

    tw.set_rls(
        role_name = rolename,
        table_name = "DimProduct",
        filter_expression = 'DimProduct[Color] = "Red"'
    )

    print(f"✅ Role '{rolename}' successfully created and configured.")

except Exception as e:
    # Check if the error is because the role already exists
    if "already exists in the collection" in str(e):
        print(f"⚠️ Role '{rolename}' already exists in the model.")
    else:
        # If it’s another unexpected error, raise it
        raise
# Out:
# StatementMeta(, 8c6137ab-72e2-443f-92dc-b7ed3872a56d, 34, Finished, Available, Finished)
# ⚠️ Role 'test' already exists in the model.

# %%
# This step saves the changes back to the model in the workspace
tw.model.SaveChanges()
# Out:
# StatementMeta(, 8c6137ab-72e2-443f-92dc-b7ed3872a56d, 32, Finished, Available, Finished)
