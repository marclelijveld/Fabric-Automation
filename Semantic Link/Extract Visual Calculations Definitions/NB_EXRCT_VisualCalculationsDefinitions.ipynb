# %% [markdown]
# # Trace visual calculations in a report and extract definitions
# This notebook extracts visual calculations from an existing report. The following steps are applied:
# - Get the report definition (base64)
# - Converts base64 to json
# - Identify visual containing visual calculations
# - Extract visual calculation definition(s) from each visual
# - Print visual calculation name, language and expression to dataframe
#
#
# <mark>**Disclaimer:** that this notebook contains AI generated code</mark>

# %% [markdown]
# ### Importing libraries and defining variables

# %%
# Importing semantic link labs packages
# %pip install semantic-link-labs
import sempy_labs as labs
import sempy_labs.report as rep
from sempy_labs.report import ReportWrapper
import json
import base64
import pandas as pd
# Out:
# StatementMeta(, 44699461-f127-49da-8579-fda7098a6699, 8, Finished, Available, Finished)
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.10.1-py3-none-any.whl.metadata (27 kB)
# Collecting semantic-link-sempy>=0.11.0 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-labs) (3.1.1)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (0.2.5)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (2023.10.3)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.0->semantic-link-labs) (8.2.3)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (8.1.2)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.0.0)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.25.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.0->semantic-link-labs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.0->semantic-link-labs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.9.3)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.10)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.8.0->powerbiclient->semantic-link-labs) (2.4.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (42.0.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.0->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.0->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->semantic-link-sempy>=0.11.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.11.0->semantic-link-labs) (0.2.2)
# Downloading semantic_link_labs-0.10.1-py3-none-any.whl (731 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 kB 28.7 MB/s eta 0:00:00
# Downloading semantic_link_sempy-0.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 81.3 MB/s eta 0:00:00:00:01
# Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 16.5 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Installing collected packages: polib, jsonpath_ng, anytree, semantic-link-sempy, semantic-link-labs
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.10.2
#     Not uninstalling semantic-link-sempy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-1352ae36-a456-4135-ad8b-71e048d6f4e4
#     Can't uninstall 'semantic-link-sempy'. No files were found to uninstall.
# Successfully installed anytree-2.13.0 jsonpath_ng-1.7.0 polib-1.2.0 semantic-link-labs-0.10.1 semantic-link-sempy-0.11.0
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
# Define variables
report_name = "Contoso Sales" # Enter the report name
report_workspace = "Visual Calculations book" # Enter the workspace in which the report exists
rpt = ReportWrapper(report=report_name, workspace=report_workspace) # Setting up the report wrapper to be used later
# Out:
# StatementMeta(, 44699461-f127-49da-8579-fda7098a6699, 10, Finished, Available, Finished)

# %% [markdown]
# ### Get report definition

# %%
# This step extracts the base64 payload for the different report elements
# if you want to reuse report elements, this can be useful, though we cannot directly extract the visual calculations
reportdef = labs.report.get_report_definition(
    report=report_name, 
    workspace=report_workspace , # defaults to the current workspace, 
    return_dataframe= True # if True, returns a dataframe. If False, returns a json dictionary.
    )
# Out:
# StatementMeta(, 44699461-f127-49da-8579-fda7098a6699, 11, Finished, Available, Finished)

# %%
# Extract and decode the JSON payload from Base64
row = reportdef[reportdef["path"] == "report.json"].iloc[0]
base64_payload = row["payload"]
json_bytes = base64.b64decode(base64_payload)
json_str = json_bytes.decode("utf-8")
json_obj = json.loads(json_str)
# Out:
# StatementMeta(, 44699461-f127-49da-8579-fda7098a6699, 14, Finished, Available, Finished)

# %% [markdown]
# ### Extracting visuals

# %%
# Recursive function to find all NativeVisualCalculation objects anywhere in a nested JSON
def find_native_visual_calculations(obj):
    results = []
    if isinstance(obj, dict):
        for k, v in obj.items():
            if k == "NativeVisualCalculation" and isinstance(v, dict):
                results.append(v)
            else:
                results.extend(find_native_visual_calculations(v))
    elif isinstance(obj, list):
        for item in obj:
            results.extend(find_native_visual_calculations(item))
    return results
# Out:
# StatementMeta(, 44699461-f127-49da-8579-fda7098a6699, 13, Finished, Available, Finished)

# %%
# trying to find the rows in the json which contain a definition like visual calculations
def find_strings_with_substring(obj, substring="NativeVisualCalculation"):
    found_strings = []
    if isinstance(obj, dict):
        for v in obj.values():
            found_strings.extend(find_strings_with_substring(v, substring))
    elif isinstance(obj, list):
        for item in obj:
            found_strings.extend(find_strings_with_substring(item, substring))
    elif isinstance(obj, str):
        if substring in obj:
            found_strings.append(obj)
    return found_strings

# Search all strings in json_obj that contain the key substring
visuals_with_vc = find_strings_with_substring(json_obj, "NativeVisualCalculation")

print(f"Found {len(visuals_with_vc)} visuals containing Visual Calculation in {report_name}")
# Out:
# StatementMeta(, 44699461-f127-49da-8579-fda7098a6699, 22, Finished, Available, Finished)
# Found 45 visuals containing Visual Calculation in Contoso Sales

# %% [markdown]
# ### Extracting visual calculations from visuals

# %%
# as a line may contain multiple visual calculations, extracting the number of visual calculations from the strings
all_nvc_objects = []

for s in visuals_with_vc:
    try:
        # Sometimes the string might be JSON escaped (like config fields)
        parsed = json.loads(s)
    except Exception:
        # Not JSON, skip or continue
        continue
    
    # Now find native visual calculations inside this parsed JSON snippet
    nvc_objs = find_native_visual_calculations(parsed)
    all_nvc_objects.extend(nvc_objs)

print(f"Extracted {len(all_nvc_objects)} NativeVisualCalculation (nvc) objects from embedded JSON strings")
# Out:
# StatementMeta(, 44699461-f127-49da-8579-fda7098a6699, 24, Finished, Available, Finished)
# Extracted 115 NativeVisualCalculation (nvc) objects from embedded JSON strings

# %%
# Build list of dictionaries to extract the Language, Expression and Name of the visual calculations
records = []
for nvc in all_nvc_objects:
    language = nvc.get("Language", "").strip()
    expression = nvc.get("Expression", "").replace('\n', ' ').strip()
    name = nvc.get("Name", "").strip()
    records.append({"Name": name, "Language": language, "Expression": expression})

# Create DataFrame
df = pd.DataFrame(records)

# Remove duplicates and reset index
df = df.drop_duplicates().reset_index(drop=True)

# Display with better formatting: no index, wrap text for expressions 
from IPython.display import display
pd.set_option('display.max_colwidth', None)  # show full Expression text without truncation

display(df.style.set_properties(**{
    'text-align': 'left',
    'white-space': 'pre-wrap',
    'word-wrap': 'break-word',
}))
# Out:
# StatementMeta(, 0d5f12b7-5e00-4474-9f60-18f07bc58ff6, 30, Finished, Available, Finished)
# <style type="text/css">
# #T_5f053_row0_col0, #T_5f053_row0_col1, #T_5f053_row0_col2, #T_5f053_row1_col0, #T_5f053_row1_col1, #T_5f053_row1_col2, #T_5f053_row2_col0, #T_5f053_row2_col1, #T_5f053_row2_col2, #T_5f053_row3_col0, #T_5f053_row3_col1, #T_5f053_row3_col2, #T_5f053_row4_col0, #T_5f053_row4_col1, #T_5f053_row4_col2, #T_5f053_row5_col0, #T_5f053_row5_col1, #T_5f053_row5_col2, #T_5f053_row6_col0, #T_5f053_row6_col1, #T_5f053_row6_col2, #T_5f053_row7_col0, #T_5f053_row7_col1, #T_5f053_row7_col2, #T_5f053_row8_col0, #T_5f053_row8_col1, #T_5f053_row8_col2, #T_5f053_row9_col0, #T_5f053_row9_col1, #T_5f053_row9_col2, #T_5f053_row10_col0, #T_5f053_row10_col1, #T_5f053_row10_col2, #T_5f053_row11_col0, #T_5f053_row11_col1, #T_5f053_row11_col2, #T_5f053_row12_col0, #T_5f053_row12_col1, #T_5f053_row12_col2, #T_5f053_row13_col0, #T_5f053_row13_col1, #T_5f053_row13_col2, #T_5f053_row14_col0, #T_5f053_row14_col1, #T_5f053_row14_col2, #T_5f053_row15_col0, #T_5f053_row15_col1, #T_5f053_row15_col2, #T_5f053_row16_col0, #T_5f053_row16_col1, #T_5f053_row16_col2, #T_5f053_row17_col0, #T_5f053_row17_col1, #T_5f053_row17_col2, #T_5f053_row18_col0, #T_5f053_row18_col1, #T_5f053_row18_col2, #T_5f053_row19_col0, #T_5f053_row19_col1, #T_5f053_row19_col2, #T_5f053_row20_col0, #T_5f053_row20_col1, #T_5f053_row20_col2, #T_5f053_row21_col0, #T_5f053_row21_col1, #T_5f053_row21_col2, #T_5f053_row22_col0, #T_5f053_row22_col1, #T_5f053_row22_col2, #T_5f053_row23_col0, #T_5f053_row23_col1, #T_5f053_row23_col2, #T_5f053_row24_col0, #T_5f053_row24_col1, #T_5f053_row24_col2, #T_5f053_row25_col0, #T_5f053_row25_col1, #T_5f053_row25_col2, #T_5f053_row26_col0, #T_5f053_row26_col1, #T_5f053_row26_col2, #T_5f053_row27_col0, #T_5f053_row27_col1, #T_5f053_row27_col2, #T_5f053_row28_col0, #T_5f053_row28_col1, #T_5f053_row28_col2, #T_5f053_row29_col0, #T_5f053_row29_col1, #T_5f053_row29_col2, #T_5f053_row30_col0, #T_5f053_row30_col1, #T_5f053_row30_col2, #T_5f053_row31_col0, #T_5f053_row31_col1, #T_5f053_row31_col2, #T_5f053_row32_col0, #T_5f053_row32_col1, #T_5f053_row32_col2, #T_5f053_row33_col0, #T_5f053_row33_col1, #T_5f053_row33_col2, #T_5f053_row34_col0, #T_5f053_row34_col1, #T_5f053_row34_col2, #T_5f053_row35_col0, #T_5f053_row35_col1, #T_5f053_row35_col2, #T_5f053_row36_col0, #T_5f053_row36_col1, #T_5f053_row36_col2, #T_5f053_row37_col0, #T_5f053_row37_col1, #T_5f053_row37_col2, #T_5f053_row38_col0, #T_5f053_row38_col1, #T_5f053_row38_col2, #T_5f053_row39_col0, #T_5f053_row39_col1, #T_5f053_row39_col2, #T_5f053_row40_col0, #T_5f053_row40_col1, #T_5f053_row40_col2, #T_5f053_row41_col0, #T_5f053_row41_col1, #T_5f053_row41_col2, #T_5f053_row42_col0, #T_5f053_row42_col1, #T_5f053_row42_col2, #T_5f053_row43_col0, #T_5f053_row43_col1, #T_5f053_row43_col2, #T_5f053_row44_col0, #T_5f053_row44_col1, #T_5f053_row44_col2, #T_5f053_row45_col0, #T_5f053_row45_col1, #T_5f053_row45_col2, #T_5f053_row46_col0, #T_5f053_row46_col1, #T_5f053_row46_col2, #T_5f053_row47_col0, #T_5f053_row47_col1, #T_5f053_row47_col2, #T_5f053_row48_col0, #T_5f053_row48_col1, #T_5f053_row48_col2, #T_5f053_row49_col0, #T_5f053_row49_col1, #T_5f053_row49_col2, #T_5f053_row50_col0, #T_5f053_row50_col1, #T_5f053_row50_col2, #T_5f053_row51_col0, #T_5f053_row51_col1, #T_5f053_row51_col2, #T_5f053_row52_col0, #T_5f053_row52_col1, #T_5f053_row52_col2, #T_5f053_row53_col0, #T_5f053_row53_col1, #T_5f053_row53_col2, #T_5f053_row54_col0, #T_5f053_row54_col1, #T_5f053_row54_col2, #T_5f053_row55_col0, #T_5f053_row55_col1, #T_5f053_row55_col2, #T_5f053_row56_col0, #T_5f053_row56_col1, #T_5f053_row56_col2, #T_5f053_row57_col0, #T_5f053_row57_col1, #T_5f053_row57_col2, #T_5f053_row58_col0, #T_5f053_row58_col1, #T_5f053_row58_col2, #T_5f053_row59_col0, #T_5f053_row59_col1, #T_5f053_row59_col2, #T_5f053_row60_col0, #T_5f053_row60_col1, #T_5f053_row60_col2, #T_5f053_row61_col0, #T_5f053_row61_col1, #T_5f053_row61_col2, #T_5f053_row62_col0, #T_5f053_row62_col1, #T_5f053_row62_col2, #T_5f053_row63_col0, #T_5f053_row63_col1, #T_5f053_row63_col2 ...
#   text-align: left;
#   white-space: pre-wrap;
#   word-wrap: break-word;
# }
# </style>
# <table id="T_5f053">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f053_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_5f053_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_5f053_level0_col2" class="col_heading level0 col2" >Expression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f053_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f053_row0_col0" class="data row0 col0" >Highlight</td>
#       <td id="T_5f053_row0_col1" class="data row0 col1" >dax</td>
#       <td id="T_5f053_row0_col2" class="data row0 col2" >VAR __h =     COLLAPSE ( EXPAND ( MAX ( [Sales Amount] ), ROWS ), ROWS ) RETURN     IF ( MONTH ( [Date] ) = [MonthSelected Value], __h * 1.2, BLANK () )</td>
#     </tr>
#     <tr>
#       <th id="T_5
